# %% [markdown]
# <h1 ><b>Data Science Project- Karachi Property</b></h1>
#
# ---

# %% [markdown]
# <h2>Problem Statement</h2>
#
#
# ---

# %% [markdown]
# Develop a predictive model to estimate house prices based on features. Specific tasks. Using data evaluate features best effect property price.

# %% [markdown]
# <h2>Objectives:</h2></br>
#
# ---
#
#
#
# ---
#
#
# The objective of this data science project is to develop a predictive model that accurately estimates the price of a house based on its features. The project involves several key tasks aimed at understanding the influential factors, enhancing the dataset, and addressing challenges related to missing data.<br/>
# **1-	Feature Importance Analysis:**<br/>
# Identify and rank the importance of different features in influencing the house price. This helps in understanding which characteristics have the most significant impact.<br/>
# **2-	Feature Engineering:**<br/>
# Explore and create new features that might better capture the underlying patterns in the data, improving the model's predictive performance.<br/>
# **3-	Addressing Missing Values:**<br/>
# Develop strategies for handling missing values in the dataset, such as imputation or exclusion of instances with missing data.<br/>

# %% [markdown]
# <h2>Business Question</h2><br/>
#
# ---
#
#
#
# ---
#
#
# When working on a house price dataset for a data science project focusing on features of the house, various business questions can be explored to extract meaningful insights. Here are some business-oriented questions related to the features of the house:<br/>
# **Feature Importance:**<br/>
# Q1- Which features have the most significant impact on the pricing of houses in the dataset?<br/>
# Q2- How do different features contribute to the overall perceived value of a property?<br/><br/>
#
# **Market Segmentation:**<br/>
# Q3-Are there distinct segments in the market based on house features (e.g., size, number of bedrooms, amenities)?<br/><br/>
# **Feature Over Property Type:**<br/>
# Q4- What are the impact of property price depending on property type ?<br/>

# %% [markdown]
# <h2>How we Intend to Address the Problem</h2>
#
# ---
#
#
#
# ---
#
#
# <p>We will visualize relation between different features colloectively and property type wise both.</p>
# <p>We will apply different regression models and select best amoung them  to estimate price </p>

# %% [markdown]
# <h2>Dataset and its Attributes</h2>
#
# ---
#
#
#
# ---
#
# We also gather dataset from zameen.com by performing web-scrapping . dataset is latest and contain below feature sets:<br/>
# we also upload datset at kaggle https://www.kaggle.com/datasets/mairasaad/karachi-forsale-property-dataset <br/>
#
# •	Page URL: The URL of the webpage where the property was published.<br/>
# •	Property Type: Categorization of the property into six types: House, FarmHouse, Upper Portion, Lower Portion, Flat, or Room.<br/>
# •	Price: The price of the property, which is the dependent feature in this dataset.<br/>
# •	City: The city where the property is located. Currently we extract only karachi data only so we are going to drop this feature<br/>
# •	Location: Different types of locations Example: Faderal B Area- Block 13<br/>
# •	Baths: Number of Bathrooms in the property<br/>
# •	Bedrooms: Number of bedrooms in the property<br/>
# •	purpose: For Rent or For Sale- Currently be have data of For sale therfore we are going to drop this feature<br/>
# •	Area Size: Area size in numbers<br/>
# •	near_by_schools: Is the property is near by School (Y/N)<br/>
# •	near_by_hospitals: Is the property is near by hospital (Y/N)<br/>
# •	near_by_airport  : Is the property is near by airport (Y/N)<br/>
# •	near_by_restaurant: Is the property is near by restaurant (Y/N)<br/>
# •	near_by_public_transport: Is the property is near by public transport (Y/N)<br/>
# •	near_by_shopping_mall: Is the property is near by shopping_mall (Y/N)<br/>
# •	parking_slot_available: Is Parking slot available (Y/N)<br/>
# refer: webscraping.py
#
#
# ---

# %% [markdown]
# <h2>Outline Design of Project</h2>
#
# ---
#
#
#
# ---
# <h3>Define Project Scope:</h3>
#
# Clearly articulate the project's goals and objectives.
# Identify the problem statement and the specific questions the data science project aims to address.<br/>
# <h3>Data Collection:</h3>
# <br/>
# Source relevant datasets, ensuring they align with the project objectives.
# Verify data quality, addressing any inconsistencies or missing values.
# Consider data privacy and compliance with ethical standards.
# <br/>
# <h3>Exploratory Data Analysis (EDA):</h3>
#
# Conduct a thorough exploration of the dataset to understand its characteristics.
# <br/>
# <b>Data Preprocessing:</b>
#
# Handle missing values.<br/>
# Checking if duplicates are available<br/>
# Perform feature scaling, normalization, or transformation as needed.<br/>
# Encode categorical variables and address outliers.<br/>
# <b>Feature Engineering:</b>
# Identify opportunities for creating new features that enhance model performance.
# Consider domain knowledge and insights gained from EDA.
# Implement feature engineering techniques to improve the dataset's representativeness.<br/>
# <h3>Visualize data distributions, correlations, and potential outliers.</h3>
# Identify patterns and relationships between variables. <br/>
#
# <h3>Train-Test Split:</h3>
#
# Divide the dataset into training and testing sets to assess model generalization.<br/>
# <h3>Model Selection:</h3>
#
# Choose appropriate machine learning algorithms based on the nature of the problem (regression).<br/>
# Experiment with multiple algorithms to identify the most suitable model.<br/>
# 1- SVN<br/>
# 2- RandomForest Regression<br/>
# 3-Linear Regression<br/>
# <h3>Model Training:</h3><br/>
#
# Train the selected model using the training dataset.
# <br/>
# <h3>Model Evaluation:</h3>
#
# Assess model performance on the testing set using relevant evaluation metrics.
# Consider business implications and interpretability of the model's predictions.
# <br/>
#
# <h3> Documentation:</h3>
# Document each step

# %% [markdown]
# **Writing data to csv file**

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA)</h2>
#
# ---
#
#
#
# ---
#
# Data preprocessing is a crucial step in the data science pipeline, especially when working with a property dataset for tasks such as predicting house prices. Here are some common preprocessing steps you might consider:</br>

# %% [markdown]
# 1- Reading file in data frame

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/property_zammen_karachi_data1.csv')
#Count data
df.count()
# Out:
# Unnamed: 0                  8975
# url                         8975
# price                       8975
# Title                       8975
# Location                    8975
# City                        8975
# Beds                        8428
# Baths                       8365
# Area                        8942
# Upload_Date                 8975
# Type                        8892
# Purpose                     8892
# near_by_schools             8975
# near_by_hospitals           8975
# near_by_airport             8975
# near_by_restaurant          8975
# near_by_public_transport    8975
# near_by_shopping_mall       8975
# parking_slot_available      8975
# today_Date                  8975
# dtype: int64

# %%
df.describe(include="all")
# Out:
#          Unnamed: 0                                                url  \
# count   8975.000000                                               8975
# unique          NaN                                               7494
# top             NaN  https://www.zameen.com//new-projects/amber_pri...
# freq            NaN                                                 18
# mean    4487.000000                                                NaN
# std     2591.003667                                                NaN
# min        0.000000                                                NaN
# 25%     2243.500000                                                NaN
# 50%     4487.000000                                                NaN
# 75%     6730.500000                                                NaN
# max     8974.000000                                                NaN
#
#             price          Title                  Location     City  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                                url       price  \
# 0           0  https://www.zameen.com//Property/dha_phase_8_d...    19 Crore
# 1           1  https://www.zameen.com//Property/dha_defence_d...    14 Crore
# 2           2  https://www.zameen.com//Property/bahria_paradi...  3.65 Crore
# 3           3  https://www.zameen.com//Property/dha_defence_d...    16 Crore
# 4           4  https://www.zameen.com//Property/karachi_bahri...  2.02 Crore
#
#                                                Title  \
# 0  500 Square Yards House For Sale In Dha Phase 8...
# 1  Dha 500 Yard Brand New Bungalow With Basement ...
# 2  Paradise Villa Luxury For Sale In Bahria Town ...
# 3  500 Yards Brand New Top Quality Bungalow For Sale
# 4  A 350 Square Yards House Located In Bahria Tow...
#
#                                          Location     City  Beds  Baths  \
# 0               DHA Phase 8 - Zone A, DHA Phase 8  Karachi   6.0    6.0
# ...

# %% [markdown]
# **checking data type**<br/>
# important to know while ploting as it is important to be in interger<br/>
# It also give info which data coulmn required type caasting

# %%
df.dtypes
# Out:
# Unnamed: 0                    int64
# url                          object
# price                        object
# Title                        object
# Location                     object
# City                         object
# Beds                        float64
# Baths                       float64
# Area                         object
# Upload_Date                  object
# Type                         object
# Purpose                      object
# near_by_schools              object
# near_by_hospitals            object
# near_by_airport              object
# near_by_restaurant           object
# near_by_public_transport     object
# near_by_shopping_mall        object
# parking_slot_available       object
# today_Date                   object
# dtype: object

# %% [markdown]
# **Dropping the duplicate**
# A Data Cleaning operation<br/>

# %%
df.shape
# Out:
# (8975, 20)

# %%
#know how many duplicate rows are there
duplicate_df=df[df.duplicated]
print(duplicate_df.shape)
# Out:
# (0, 20)

# %%
#Now let us remove the duplicate
#df=df.drop_duplicates()

# %%
#print(df.shape)

# %% [markdown]
# **Drop features not required** <br/>
# It remove these not required coulmns from df<br/>
# Currently we are droping Purpose and upload date column as all values are For Sale we have to revisit after calculating upload date

# %%
df=df.drop(['url','City','Purpose','today_Date'],axis=1)

# %%
df=df.drop(['Upload_Date','Upload_Date','Title'],axis=1)

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.dtypes
# Out:
# price                        object
# Location                     object
# Beds                        float64
# Baths                       float64
# Area                         object
# Type                         object
# near_by_schools              object
# near_by_hospitals            object
# near_by_airport              object
# near_by_restaurant           object
# near_by_public_transport     object
# near_by_shopping_mall        object
# parking_slot_available       object
# dtype: object

# %% [markdown]
# **Handling missing values**<br/>
# Identify and address missing values in the dataset. This could involve imputing missing values (replacing them with estimated values based on other data), removing instances with missing values, or using advanced imputation techniques.

# %%
print(df.isnull().sum())
# Out:
# price                         0
# Location                      0
# Beds                        547
# Baths                       610
# Area                         33
# Type                         83
# near_by_schools               0
# near_by_hospitals             0
# near_by_airport               0
# near_by_restaurant            0
# near_by_public_transport      0
# near_by_shopping_mall         0
# parking_slot_available        0
# dtype: int64

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (8265, 13)

# %% [markdown]
# Currently ignoring city as all data is of karachi<br/>
# url is not required

# %% [markdown]
# **type cast data type as all are object**<br/>
# Price--> float<br/>
# Beds-->int <br/>
# Baths--> int <br/>
# Type--> int 1- flat 2-house<br/>
# Purpose--> int 1-Sale 2-Rent <br/>
# near_by_schools-> int 1 or 0<br/>
# near_by_hospitals           <br/>
# near_by_airport             <br/>
# near_by_restaurant          <br/>
# near_by_public_transport    <br/>
# near_by_public_transport    <br/>
# parking_slot_available      <br/>

# %% [markdown]
# **as price in format 1.55 Crore
#  change it to digital first**

# %%
df['price'].unique()
# Out:
# array(['19 Crore', '14 Crore', '3.65 Crore', '16 Crore', '2.02 Crore',
#        '10.5 Crore', '1.2 Crore', '3.75 Crore', '2.1 Crore', '1.25 Crore',
#        '6.3 Crore', '3.33 Crore', '15 Crore', '20 Crore', '8.5 Crore',
#        '3 Crore', '1.7 Crore', '3.7 Crore', '3.25 Crore', '2.48 Crore',
#        '22 Crore', '8.75 Crore', '12.75 Crore', '2.05 Crore', '1.4 Crore',
#        '2.5 Crore', '2.45 Crore', '12.5 Crore', '76 Lakh', '13 Crore',
#        '1.55 Crore', '2.35 Crore', '5.35 Crore', '4.15 Crore', '2 Crore',
#        '1.3 Crore', '7.65 Crore', '4.1 Crore', '27.84 Lakh', '9.2 Crore',
#        '3.51 Crore', '4 Crore', '6.5 Crore', '5.5 Crore', '1.65 Crore',
#        '10.14 Crore', '10.67 Crore', '9.79 Crore', '9.3 Crore',
#        '5.71 Crore', '4.6 Crore', '7.75 Crore', '7.1 Crore', '4.18 Crore',
#        '3.3 Crore', '21.5 Crore', '47.56 Lakh', '3.35 Crore',
#        '1.27 Crore', '2.99 Crore', '1.6 Crore', '16.5 Crore', '3.2 Crore',
# ...

# %%
df['price']=df['price'].replace({'price':'0',' Arab':'*1e9',' Thousand':'*1e3',' Lakh': '*1e5', ' Crore': '*1e7'}, regex=True)

# %%
df['price'].unique()
# Out:
# array(['19*1e7', '14*1e7', '3.65*1e7', '16*1e7', '2.02*1e7', '10.5*1e7',
#        '1.2*1e7', '3.75*1e7', '2.1*1e7', '1.25*1e7', '6.3*1e7',
#        '3.33*1e7', '15*1e7', '20*1e7', '8.5*1e7', '3*1e7', '1.7*1e7',
#        '3.7*1e7', '3.25*1e7', '2.48*1e7', '22*1e7', '8.75*1e7',
#        '12.75*1e7', '2.05*1e7', '1.4*1e7', '2.5*1e7', '2.45*1e7',
#        '12.5*1e7', '76*1e5', '13*1e7', '1.55*1e7', '2.35*1e7', '5.35*1e7',
#        '4.15*1e7', '2*1e7', '1.3*1e7', '7.65*1e7', '4.1*1e7', '27.84*1e5',
#        '9.2*1e7', '3.51*1e7', '4*1e7', '6.5*1e7', '5.5*1e7', '1.65*1e7',
#        '10.14*1e7', '10.67*1e7', '9.79*1e7', '9.3*1e7', '5.71*1e7',
#        '4.6*1e7', '7.75*1e7', '7.1*1e7', '4.18*1e7', '3.3*1e7',
#        '21.5*1e7', '47.56*1e5', '3.35*1e7', '1.27*1e7', '2.99*1e7',
#        '1.6*1e7', '16.5*1e7', '3.2*1e7', '62*1e5', '4.58*1e7', '3.1*1e7',
#        '65*1e5', '4.2*1e7', '17*1e5', '4.75*1e7', '11*1e7', '9.8*1e7',
# ...

# %%
df['price']=df['price'].map(pd.eval)

# %%
df['price'].unique()
# Out:
# array([1.900e+08, 1.400e+08, 3.650e+07, 1.600e+08, 2.020e+07, 1.050e+08,
#        1.200e+07, 3.750e+07, 2.100e+07, 1.250e+07, 6.300e+07, 3.330e+07,
#        1.500e+08, 2.000e+08, 8.500e+07, 3.000e+07, 1.700e+07, 3.700e+07,
#        3.250e+07, 2.480e+07, 2.200e+08, 8.750e+07, 1.275e+08, 2.050e+07,
#        1.400e+07, 2.500e+07, 2.450e+07, 1.250e+08, 7.600e+06, 1.300e+08,
#        1.550e+07, 2.350e+07, 5.350e+07, 4.150e+07, 2.000e+07, 1.300e+07,
#        7.650e+07, 4.100e+07, 2.784e+06, 9.200e+07, 3.510e+07, 4.000e+07,
#        6.500e+07, 5.500e+07, 1.650e+07, 1.014e+08, 1.067e+08, 9.790e+07,
#        9.300e+07, 5.710e+07, 4.600e+07, 7.750e+07, 7.100e+07, 4.180e+07,
#        3.300e+07, 2.150e+08, 4.756e+06, 3.350e+07, 1.270e+07, 2.990e+07,
#        1.600e+07, 1.650e+08, 3.200e+07, 6.200e+06, 4.580e+07, 3.100e+07,
#        6.500e+06, 4.200e+07, 1.700e+06, 4.750e+07, 1.100e+08, 9.800e+07,
#        7.500e+07, 2.400e+07, 1.500e+07, 1.800e+07, 1.000e+08, 1.280e+07,
# ...

# %%
df['price']=df['price'].astype(int)

# %%
df['price'].unique()
# Out:
# array([ 190000000,  140000000,   36500000,  160000000,   20200000,
#         105000000,   12000000,   37500000,   21000000,   12500000,
#          63000000,   33300000,  150000000,  200000000,   85000000,
#          30000000,   17000000,   37000000,   32500000,   24800000,
#         220000000,   87500000,  127500000,   20500000,   14000000,
#          25000000,   24500000,  125000000,    7600000,  130000000,
#          15500000,   23500000,   53500000,   41500000,   20000000,
#          13000000,   76500000,   41000000,    2784000,   92000000,
#          35100000,   40000000,   65000000,   55000000,   16500000,
#         101400000,  106700000,   97899999,   93000000,   57100000,
#          46000000,   77500000,   71000000,   41800000,   33000000,
#         215000000,    4756000,   33500000,   12700000,   29900000,
#          16000000,  165000000,   32000000,    6200000,   45800000,
#          31000000,    6500000,   42000000,    1700000,   47500000,
# ...

# %% [markdown]
# **converting String values to integ**er

# %%
df['Beds'].unique()
# Out:
# array([ 6.,  5.,  4.,  9.,  3.,  1.,  7., 10.,  2.,  8., 11.])

# %%
df['Beds']=df['Beds'].astype(int)

# %%
df['Beds'].unique()
# Out:
# array([ 6,  5,  4,  9,  3,  1,  7, 10,  2,  8, 11])

# %%
df['Baths'].unique()
# Out:
# array([ 6.,  5.,  4.,  3.,  2.,  1.,  7.,  8., 10.,  9.])

# %%
df['Baths']=df['Baths'].astype(int)

# %%
df['Baths'].unique()
# Out:
# array([ 6,  5,  4,  3,  2,  1,  7,  8, 10,  9])

# %%
df['Area'].unique()
# Out:
# array(['500 Sq. Yd.', '350 Sq. Yd.', '400 Sq. Yd.', '120 Sq. Yd.',
#        '240 Sq. Yd.', '156 Sq. Yd.', '356 Sq. Yd.', '95 Sq. Yd.',
#        '600 Sq. Yd.', '233 Sq. Yd.', '139 Sq. Yd.', '277 Sq. Yd.',
#        '244 Sq. Yd.', '239 Sq. Yd.', '189 Sq. Yd.', '1,000 Sq. Yd.',
#        '152 Sq. Yd.', '256 Sq. Yd.', '222 Sq. Yd.', '106 Sq. Yd.',
#        '172 Sq. Yd.', '194 Sq. Yd.', '183 Sq. Yd.', '235 Sq. Yd.',
#        '375 Sq. Yd.', '300 Sq. Yd.', '35 Sq. Yd.', '427 Sq. Yd.',
#        '117 Sq. Yd.', '211 Sq. Yd.', '265 Sq. Yd.', '158 Sq. Yd.',
#        '367 Sq. Yd.', '133 Sq. Yd.', '272 Sq. Yd.', '94 Sq. Yd.',
#        '274 Sq. Yd.', '251 Sq. Yd.', '150 Sq. Yd.', '161 Sq. Yd.',
#        '289 Sq. Yd.', '48 Sq. Yd.', '201 Sq. Yd.', '178 Sq. Yd.',
#        '180 Sq. Yd.', '200 Sq. Yd.', '83 Sq. Yd.', '267 Sq. Yd.',
#        '56 Sq. Yd.', '428 Sq. Yd.', '160 Sq. Yd.', '125 Sq. Yd.',
#        '100 Sq. Yd.', '144 Sq. Yd.', '412 Sq. Yd.', '101 Sq. Yd.',
# ...

# %%
df['Area']=df['Area'].replace({' Sq. Yd.':'',',':''}, regex=True)

# %%
df['Area'].fillna(0, inplace = True)

# %%
df['Area']=df['Area'].astype('int')

# %%
df['Area'].unique()
# Out:
# array([  500,   350,   400,   120,   240,   156,   356,    95,   600,
#          233,   139,   277,   244,   239,   189,  1000,   152,   256,
#          222,   106,   172,   194,   183,   235,   375,   300,    35,
#          427,   117,   211,   265,   158,   367,   133,   272,    94,
#          274,   251,   150,   161,   289,    48,   201,   178,   180,
#          200,    83,   267,    56,   428,   160,   125,   100,   144,
#          412,   101,   309,   212,   320,    92,   682,  1634,   122,
#          250,   135,   115,    60,   243,   137,   800,  2400,   411,
#          167,   615,  2000,  1300,    67,    78,    90,   111,   333,
#           45,   157,   275,   311,   666,   136,   308,    72,  1500,
#          110,   217,   266,   260,   450,   292,   140,    79,   128,
#          206,    85,    97,   138,   186,    62,   220,   377,   286,
#           80,   389,   216,  1600,   227,   199,   550,  2500,   103,
# ...

# %% [markdown]
# **Renaming Area to Area_sq_yd to mae it more understandable**

# %%
df=df.rename(columns={'Area':'Area_sq_yd'})

# %% [markdown]
# **Replacing type**</br>
# <table>
# <th>Actual value</th>
# <th>Replace Value</th>
# <tr>
# <td>House</td>
# <td>1</td>
# </tr>
# <tr>
# <td>Flat</td>
# <td>2</td>
# </tr>
# <tr>
# <td>Upper Portion</td>
# <td>3</td>
# </tr>
# <tr>
# <td>Lower Portion</td>
# <td>4</td>
# </tr>
# <tr>
# <td>Farm House</td>
# <td>5</td>
# </tr>
# <tr>
# <td>Penthouse</td>
# <td>6</td>
# </tr>
# </table>

# %%
df['Type'].unique()
# Out:
# array(['House', 'Upper Portion', 'Flat', 'Lower Portion', 'Penthouse',
#        'Farm House'], dtype=object)

# %%
df['Type']=df['Type'].replace({'House':'1','Flat':'2','Upper Portion':'3','Lower Portion':'4','Farm House':'5','Penthouse':'6'}, regex=True)

# %%
df['Type']=df['Type'].replace({'Farm 1':'5'}, regex=True)

# %%
df['Type'].astype('int')
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 8970    2
# 8971    2
# 8972    2
# 8973    2
# 8974    2
# Name: Type, Length: 8265, dtype: int64

# %%
df['Type'].unique()
# Out:
# array(['1', '3', '2', '4', '6', '5'], dtype=object)

# %%
df['near_by_schools'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df['near_by_schools']=df['near_by_schools'].replace({'Y':'1','N':'0'}, regex=True).astype('int')

# %%
df['near_by_schools'].unique()
# Out:
# array([1, 0])

# %%
df['near_by_hospitals'].unique()
df['near_by_hospitals']=df['near_by_hospitals'].replace({'Y':'1','N':'0'}, regex=True).astype('int')
df['near_by_hospitals'].unique()
# Out:
# array([1, 0])

# %%
df['near_by_airport'].unique()
df['near_by_airport']=df['near_by_airport'].replace({'Y':'1','N':'0'}, regex=True).astype('int')
df['near_by_airport'].unique()
# Out:
# array([0, 1])

# %%
df['near_by_restaurant'].unique()
df['near_by_restaurant']=df['near_by_restaurant'].replace({'Y':'1','N':'0'}, regex=True).astype('int')
df['near_by_restaurant'].unique()
# Out:
# array([1, 0])

# %%
df['near_by_public_transport'].unique()
df['near_by_public_transport']=df['near_by_public_transport'].replace({'Y':'1','N':'0'}, regex=True).astype('int')
df['near_by_public_transport'].unique()
# Out:
# array([1, 0])

# %%
df['near_by_shopping_mall'].unique()
df['near_by_shopping_mall']=df['near_by_shopping_mall'].replace({'Y':'1','N':'0'}, regex=True).astype('int')
df['near_by_shopping_mall'].unique()
# Out:
# array([1, 0])

# %%
df['parking_slot_available'].unique()
df['parking_slot_available']=df['parking_slot_available'].replace({'Y':'1','N':'0'}, regex=True).astype('int')
df['parking_slot_available'].unique()
# Out:
# array([1, 0])

# %%
df.value_counts("Location")
# Out:
# Location
# DHA Phase 6, DHA Defence                 330
# DHA Phase 8, DHA Defence                 272
# Askari 5 - Sector J, Askari 5            265
# Bahria Town Karachi, Karachi             245
# Falcon Complex New Malir, Malir          197
#                                         ...
# Nazimabad 1 - Block E, Nazimabad 1         1
# Nazimabad 1 - Block F, Nazimabad 1         1
# Nazimabad 2 - Block A, Nazimabad 2         1
# Nazimabad 2 - Block B, Nazimabad 2         1
# Zulfiqar Commercial Area, DHA Phase 8      1
# Length: 622, dtype: int64

# %%
df.Location=df.Location.str.split(' - ').str[0]

# %%
df.Location=df.Location.str.split(',').str[0]

# %%
df.value_counts("Location")
# Out:
# Location
# Gulistan-e-Jauhar           682
# Gulshan-e-Iqbal             635
# North Nazimabad             450
# Askari 5                    430
# Bahria Town                 385
#                            ...
# PHA Maymar Towers             1
# Emaar Pearl Tower 3           1
# Euro Clock Tower              1
# Falaknaz Excellency           1
# Zulfiqar Commercial Area      1
# Length: 388, dtype: int64

# %%
df1=df

# %%
df1.count()
# Out:
# price                       8265
# Location                    8265
# Beds                        8265
# Baths                       8265
# Area_sq_yd                  8265
# Type                        8265
# near_by_schools             8265
# near_by_hospitals           8265
# near_by_airport             8265
# near_by_restaurant          8265
# near_by_public_transport    8265
# near_by_shopping_mall       8265
# parking_slot_available      8265
# dtype: int64

# %%
df1.Location=df1.Location.str.replace('\d+', '')
# Out:
# <ipython-input-55-ea87e13c8c7d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1.Location=df1.Location.str.replace('\d+', '')

# %%
df1.value_counts("Location")
# Out:
# Location
# DHA Phase                   989
# Gulistan-e-Jauhar           682
# Gulshan-e-Iqbal             635
# North Nazimabad             450
# Askari                      448
#                            ...
# Pir Ahmed Zaman Town          1
# Euro Clock Tower              1
# Pilibhit                      1
# Petal Residency               1
# Zulfiqar Commercial Area      1
# Length: 365, dtype: int64

# %%
df1.groupby('Location').filter(lambda x : len(x)<110).count()
# Out:
# price                       3291
# Location                    3291
# Beds                        3291
# Baths                       3291
# Area_sq_yd                  3291
# Type                        3291
# near_by_schools             3291
# near_by_hospitals           3291
# near_by_airport             3291
# near_by_restaurant          3291
# near_by_public_transport    3291
# near_by_shopping_mall       3291
# parking_slot_available      3291
# dtype: int64

# %%
df1=df1.groupby('Location').filter(lambda x : len(x)>110)

# %%
df1.value_counts("Location")
# Out:
# Location
# DHA Phase                   989
# Gulistan-e-Jauhar           682
# Gulshan-e-Iqbal             635
# North Nazimabad             450
# Askari                      448
# Bahria Town                 385
# Bahria Town Karachi         245
# Clifton                     205
# Falcon Complex New Malir    197
# Federal B Area              172
# North Karachi               168
# Saadi Town                  142
# Gulshan-e-Maymar            140
# PECHS Block                 116
# dtype: int64

# %%
df1.Location=df1.Location.str.replace('Bahria Town Karachi', 'Bahria Town')

# %%
df1.value_counts("Location")
# Out:
# Location
# DHA Phase                   989
# Gulistan-e-Jauhar           682
# Gulshan-e-Iqbal             635
# Bahria Town                 630
# North Nazimabad             450
# Askari                      448
# Clifton                     205
# Falcon Complex New Malir    197
# Federal B Area              172
# North Karachi               168
# Saadi Town                  142
# Gulshan-e-Maymar            140
# PECHS Block                 116
# dtype: int64

# %% [markdown]
# Location
# DHA Phase                   1
# Gulistan-e-Jauhar           2
# Gulshan-e-Iqbal             3
# North Nazimabad             4
# Askari                      5
# Bahria Town                 6
# Clifton                    7
# Falcon Complex New Malir    8
# Federal B Area              9
# North Karachi               10
# Saadi Town                  11
# Gulshan-e-Maymar            12
# PECHS Block                13
# DHA Phase  Extension        14

# %%
df1['Location']=df1['Location'].replace({'DHA Phase':'1','Gulistan-e-Jauhar':'2',
                                       'Gulshan-e-Iqbal':'3','Bahria Town':'4',
                                       'North Nazimabad':'5',
                                       'Askari':'6',
                                       'Clifton':'7','Falcon Complex New Malir':'8',
                                       'Federal B Area':'9','North Karachi':'10',
                                       'Saadi Town':'11','Gulshan-e-Maymar':'12','PECHS Block':'13'}, regex=True)

# %%
df1.count()
# Out:
# price                       4974
# Location                    4974
# Beds                        4974
# Baths                       4974
# Area_sq_yd                  4974
# Type                        4974
# near_by_schools             4974
# near_by_hospitals           4974
# near_by_airport             4974
# near_by_restaurant          4974
# near_by_public_transport    4974
# near_by_shopping_mall       4974
# parking_slot_available      4974
# dtype: int64

# %%
df1['Location'].value_counts()[:].plot(kind='barh')
# Out:
# <Axes: >

# %%
df1.head()
# Out:
#        price Location  Beds  Baths  Area_sq_yd Type  near_by_schools  \
# 0  190000000       1      6      6         500    1                1
# 1  140000000       1      6      6         500    1                1
# 3  160000000       1      6      6         500    1                1
# 4   20200000        4     4      4         350    1                1
# 5  105000000        3     9      6         400    1                1
#
#    near_by_hospitals  near_by_airport  near_by_restaurant  \
# 0                  1                0                   1
# 1                  1                0                   1
# 3                  1                1                   1
# 4                  1                1                   1
# 5                  1                1                   1
#
#    near_by_public_transport  near_by_shopping_mall  parking_slot_available
# 0                         1                      1                       1
# ...

# %% [markdown]
# **Write clean dataset into new file**

# %%
file_name = '/content/drive/MyDrive/property_zammen_karachi_1_cleaning.csv'
df1.to_csv(file_name, encoding='utf-8')

# %% [markdown]
# **Reading file**

# %%
import pandas as pd
df3=pd.read_csv('/content/drive/MyDrive/property_zammen_karachi_1_cleaning.csv')

# %%
df3.head()
# Out:
#    Unnamed: 0      price  Location  Beds  Baths  Area_sq_yd  Type  \
# 0           0  190000000         1     6      6         500     1
# 1           1  140000000         1     6      6         500     1
# 2           3  160000000         1     6      6         500     1
# 3           4   20200000         4     4      4         350     1
# 4           5  105000000         3     9      6         400     1
#
#    near_by_schools  near_by_hospitals  near_by_airport  near_by_restaurant  \
# 0                1                  1                0                   1
# 1                1                  1                0                   1
# 2                1                  1                1                   1
# 3                1                  1                1                   1
# 4                1                  1                1                   1
#
#    near_by_public_transport  near_by_shopping_mall  parking_slot_available
# ...

# %%
df3.count()
# Out:
# Unnamed: 0                  4974
# price                       4974
# Location                    4974
# Beds                        4974
# Baths                       4974
# Area_sq_yd                  4974
# Type                        4974
# near_by_schools             4974
# near_by_hospitals           4974
# near_by_airport             4974
# near_by_restaurant          4974
# near_by_public_transport    4974
# near_by_shopping_mall       4974
# parking_slot_available      4974
# dtype: int64

# %%
import seaborn as sb
sb.boxplot(x=pd.to_numeric(df3['price']))
# Out:
# <Axes: xlabel='price'>

# %%
sb.boxplot(x=pd.to_numeric(df3['Area_sq_yd']))
# Out:
# <Axes: xlabel='Area_sq_yd'>

# %% [markdown]
# **Histrogram of Property based on location**

# %%
import matplotlib.pyplot as plt

df3.Area_sq_yd.value_counts().nlargest(80).plot(kind='bar',figsize=(10,5))
plt.title('No. of Properties Area Square Yard Wise')
plt.ylabel('No. of properties')
plt.xlabel('Area Square Yard')
# Out:
# Text(0.5, 0, 'Area Square Yard')

# %%
df3.Area_sq_yd.value_counts()
# Out:
# 500     593
# 200     325
# 240     315
# 120     288
# 400     181
#        ...
# 3667      1
# 109       1
# 119       1
# 268       1
# 199       1
# Name: Area_sq_yd, Length: 239, dtype: int64

# %%
df1.groupby('Area_sq_yd').filter(lambda x : len(x)<25).count()
# Out:
# price                       854
# Location                    854
# Beds                        854
# Baths                       854
# Area_sq_yd                  854
# Type                        854
# near_by_schools             854
# near_by_hospitals           854
# near_by_airport             854
# near_by_restaurant          854
# near_by_public_transport    854
# near_by_shopping_mall       854
# parking_slot_available      854
# dtype: int64

# %%
df1=df1.groupby('Area_sq_yd').filter(lambda x : len(x)>25).count()

# %%
sb.scatterplot(data=df3, x="price", y="Area_sq_yd")
# Out:
# <Axes: xlabel='price', ylabel='Area_sq_yd'>

# %% [markdown]
# **Remove outlier**

# %%
df3=df3[df3.Area_sq_yd <1000]

# %%
sb.scatterplot(data=df3, x="price", y="Area_sq_yd")
# Out:
# <Axes: xlabel='price', ylabel='Area_sq_yd'>

# %%
df3.count()
# Out:
# Unnamed: 0                  4788
# price                       4788
# Location                    4788
# Beds                        4788
# Baths                       4788
# Area_sq_yd                  4788
# Type                        4788
# near_by_schools             4788
# near_by_hospitals           4788
# near_by_airport             4788
# near_by_restaurant          4788
# near_by_public_transport    4788
# near_by_shopping_mall       4788
# parking_slot_available      4788
# dtype: int64

# %%
df3[df3.Area_sq_yd <1000].count()
# Out:
# Unnamed: 0                  4788
# price                       4788
# Location                    4788
# Beds                        4788
# Baths                       4788
# Area_sq_yd                  4788
# Type                        4788
# near_by_schools             4788
# near_by_hospitals           4788
# near_by_airport             4788
# near_by_restaurant          4788
# near_by_public_transport    4788
# near_by_shopping_mall       4788
# parking_slot_available      4788
# dtype: int64

# %%
df3=df3[df3.price <100000000]
df3=df3[df3.Area_sq_yd <1000]
df3=df3[df3.Type <6]

# %%
df3.shape
# Out:
# (4188, 14)

# %%
df_sorted = df3.sort_values('price', ascending=False)
df_sorted
# Out:
#       Unnamed: 0     price  Location  Beds  Baths  Area_sq_yd  Type  \
# 2087        3528  99900000         9     8      6         400     1
# 2046        3456  99900000         9     8      6         400     1
# 1127        1956  99500000         1     5      6         500     1
# 78           158  99500000         8     5      5          56     1
# 1885        3200  99500000         8     5      5         500     1
# ...          ...       ...       ...   ...    ...         ...   ...
# 2964        5391   1500000        12     2      2          83     2
# 589         1006    210000         1     4      4         600     3
# 2019        3412    150000         3     2      2         122     2
# 2732        4810    150000         3     2      2         122     2
# 2759        4858    150000         3     2      2         122     2
#
#       near_by_schools  near_by_hospitals  near_by_airport  near_by_restaurant  \
# ...

# %%
sb.boxplot(x=pd.to_numeric(df3['Area_sq_yd']))
# Out:
# <Axes: xlabel='Area_sq_yd'>

# %%
sb.boxplot(x=pd.to_numeric(df3['price']))
# Out:
# <Axes: xlabel='price'>

# %%
import matplotlib.pyplot as plt

df3.Area_sq_yd.value_counts().nlargest(50).plot(kind='bar',figsize=(10,5))
plt.title('No. of Properties Area Square Yard Wise')
plt.ylabel('No. of properties')
plt.xlabel('Area Square Yard')
# Out:
# Text(0.5, 0, 'Area Square Yard')

# %%
import matplotlib.pyplot as plt

df3.Location.value_counts().nlargest(40).plot(kind='bar',figsize=(10,5))
plt.title('No. Location wise')
plt.ylabel('No. of properties')
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')

# %%
import matplotlib.pyplot as plt

df3.Type.value_counts().nlargest(40).plot(kind='bar',figsize=(10,5))
plt.title('No. Property Tpe')
plt.ylabel('No. of properties')
plt.xlabel('Property Type')
# Out:
# Text(0.5, 0, 'Property Type')

# %%
df3.count()
# Out:
# Unnamed: 0                  4188
# price                       4188
# Location                    4188
# Beds                        4188
# Baths                       4188
# Area_sq_yd                  4188
# Type                        4188
# near_by_schools             4188
# near_by_hospitals           4188
# near_by_airport             4188
# near_by_restaurant          4188
# near_by_public_transport    4188
# near_by_shopping_mall       4188
# parking_slot_available      4188
# dtype: int64

# %%
df3 = df3.loc[:, ~df3.columns.str.contains('^Unnamed')]

# %%
plt.figure(figsize=(10,5))
c=df3.corr()# correlation
sb.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %%
sb.scatterplot(data=df3, x="price", y="Location")
# Out:
# <Axes: xlabel='price', ylabel='Location'>

# %% [markdown]
# <h1>House Wise Corelation</h1>
#
# ---
#
#
#
# ---

# %%
df_House = df3[df3.Type.isin([1])]
plt.figure(figsize=(10,5))
c=df_House.corr()# correlation
sb.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %%
sb.boxplot(x=pd.to_numeric(df_House['Area_sq_yd']))
# Out:
# <Axes: xlabel='Area_sq_yd'>

# %%
sb.boxplot(x=pd.to_numeric(df_House['price']))
# Out:
# <Axes: xlabel='price'>

# %%
df_House.count()
# Out:
# price                       1957
# Location                    1957
# Beds                        1957
# Baths                       1957
# Area_sq_yd                  1957
# Type                        1957
# near_by_schools             1957
# near_by_hospitals           1957
# near_by_airport             1957
# near_by_restaurant          1957
# near_by_public_transport    1957
# near_by_shopping_mall       1957
# parking_slot_available      1957
# dtype: int64

# %%
df_House[df_House.Area_sq_yd >800].count()
# Out:
# price                       1
# Location                    1
# Beds                        1
# Baths                       1
# Area_sq_yd                  1
# Type                        1
# near_by_schools             1
# near_by_hospitals           1
# near_by_airport             1
# near_by_restaurant          1
# near_by_public_transport    1
# near_by_shopping_mall       1
# parking_slot_available      1
# dtype: int64

# %%
df_House=df_House[df_House.Area_sq_yd >800]

# %%
df_House = df3[df3.Type.isin([1])]
plt.figure(figsize=(10,5))
c=df_House.corr()# correlation
sb.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %%
sb.scatterplot(data=df_House, x="price", y="Location")
# Out:
# <Axes: xlabel='price', ylabel='Location'>

# %% [markdown]
# <h1>Flat Wise Corelation</h1>
#
# ---
#
#
#
# ---

# %%
df_flat = df3[df3.Type.isin([2])]
plt.figure(figsize=(10,5))
c=df_flat.corr()# correlation
sb.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %%
sb.boxplot(x=pd.to_numeric(df_flat['Area_sq_yd']))
# Out:
# <Axes: xlabel='Area_sq_yd'>

# %%
sb.boxplot(x=pd.to_numeric(df_flat['price']))
# Out:
# <Axes: xlabel='price'>

# %%
df_flat.Area_sq_yd
# Out:
# 8       233
# 9       277
# 10      244
# 11      239
# 12      189
#        ...
# 4969    267
# 4970    267
# 4971    211
# 4972    189
# 4973    189
# Name: Area_sq_yd, Length: 1754, dtype: int64

# %%
df_flat.count()
# Out:
# price                       1754
# Location                    1754
# Beds                        1754
# Baths                       1754
# Area_sq_yd                  1754
# Type                        1754
# near_by_schools             1754
# near_by_hospitals           1754
# near_by_airport             1754
# near_by_restaurant          1754
# near_by_public_transport    1754
# near_by_shopping_mall       1754
# parking_slot_available      1754
# dtype: int64

# %%
df_flat[df_flat.Area_sq_yd >400].count()
# Out:
# price                       13
# Location                    13
# Beds                        13
# Baths                       13
# Area_sq_yd                  13
# Type                        13
# near_by_schools             13
# near_by_hospitals           13
# near_by_airport             13
# near_by_restaurant          13
# near_by_public_transport    13
# near_by_shopping_mall       13
# parking_slot_available      13
# dtype: int64

# %%
df_flat[df_flat.Area_sq_yd <400].count()
# Out:
# price                       1739
# Location                    1739
# Beds                        1739
# Baths                       1739
# Area_sq_yd                  1739
# Type                        1739
# near_by_schools             1739
# near_by_hospitals           1739
# near_by_airport             1739
# near_by_restaurant          1739
# near_by_public_transport    1739
# near_by_shopping_mall       1739
# parking_slot_available      1739
# dtype: int64

# %%
df_flat=df_flat[df_flat.Area_sq_yd <400]

# %%
sb.boxplot(x=pd.to_numeric(df_flat['price']))
# Out:
# <Axes: xlabel='price'>

# %%
df_flat[df_flat.price >60000000 ].count()
# Out:
# price                       21
# Location                    21
# Beds                        21
# Baths                       21
# Area_sq_yd                  21
# Type                        21
# near_by_schools             21
# near_by_hospitals           21
# near_by_airport             21
# near_by_restaurant          21
# near_by_public_transport    21
# near_by_shopping_mall       21
# parking_slot_available      21
# dtype: int64

# %%
df_flat=df_flat[df_flat.price <60000000 ]

# %%
sb.boxplot(x=pd.to_numeric(df_flat['price']))
# Out:
# <Axes: xlabel='price'>

# %%
df_flat.count()
# Out:
# price                       1713
# Location                    1713
# Beds                        1713
# Baths                       1713
# Area_sq_yd                  1713
# Type                        1713
# near_by_schools             1713
# near_by_hospitals           1713
# near_by_airport             1713
# near_by_restaurant          1713
# near_by_public_transport    1713
# near_by_shopping_mall       1713
# parking_slot_available      1713
# dtype: int64

# %%
plt.figure(figsize=(10,5))
c=df_flat.corr()# correlation
sb.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %%
sb.scatterplot(data=df_flat, x="price", y="Location")
# Out:
# <Axes: xlabel='price', ylabel='Location'>

# %% [markdown]
# <h1>Upper Portion Wise Corelation</h1>
#
# ---
#
#
#
# ---

# %%
df_Upper_portion = df3[df3.Type.isin([3])]
plt.figure(figsize=(10,5))
c=df_Upper_portion.corr()# correlation
sb.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %%
sb.boxplot(x=pd.to_numeric(df_Upper_portion['price']))
# Out:
# <Axes: xlabel='price'>

# %%
df_Upper_portion[df_Upper_portion.price>70000000].count()
# Out:
# price                       1
# Location                    1
# Beds                        1
# Baths                       1
# Area_sq_yd                  1
# Type                        1
# near_by_schools             1
# near_by_hospitals           1
# near_by_airport             1
# near_by_restaurant          1
# near_by_public_transport    1
# near_by_shopping_mall       1
# parking_slot_available      1
# dtype: int64

# %%
df_Upper_portion=df_Upper_portion[df_Upper_portion.price<70000000]

# %%
df_Upper_portion['Area_sq_yd']
# Out:
# 5       120
# 36      211
# 52      180
# 90      200
# 114     122
#        ...
# 4877    150
# 4882    150
# 4883    267
# 4909    100
# 4967    100
# Name: Area_sq_yd, Length: 360, dtype: int64

# %%
sb.boxplot(x=pd.to_numeric(df_Upper_portion['Area_sq_yd']))
# Out:
# <Axes: xlabel='Area_sq_yd'>

# %%
df_Upper_portion[df_Upper_portion.Area_sq_yd>400].count()
# Out:
# price                       5
# Location                    5
# Beds                        5
# Baths                       5
# Area_sq_yd                  5
# Type                        5
# near_by_schools             5
# near_by_hospitals           5
# near_by_airport             5
# near_by_restaurant          5
# near_by_public_transport    5
# near_by_shopping_mall       5
# parking_slot_available      5
# dtype: int64

# %%
df_Upper_portion=df_Upper_portion[df_Upper_portion.Area_sq_yd<400]

# %%
plt.figure(figsize=(10,5))
c=df_Upper_portion.corr()# correlation
sb.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %%
sb.scatterplot(data=df_Upper_portion, x="price", y="Location")
# Out:
# <Axes: xlabel='price', ylabel='Location'>

# %% [markdown]
# <h1>Lower Portion Wise Corelation</h1>
#
# ---
#
#
#
# ---

# %%
df_Lowerr_portion = df3[df3.Type.isin([4])]
plt.figure(figsize=(10,5))
c=df_Lowerr_portion.corr()# correlation
sb.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %%
sb.boxplot(x=pd.to_numeric(df_Lowerr_portion['Area_sq_yd']))
# Out:
# <Axes: xlabel='Area_sq_yd'>

# %%
df_Lowerr_portion.Area_sq_yd[df_Lowerr_portion.Area_sq_yd>400].count()
# Out:
# 2

# %%
df_Lowerr_portion=df_Lowerr_portion[df_Lowerr_portion.Area_sq_yd<400]

# %%
sb.boxplot(x=pd.to_numeric(df_Lowerr_portion['price']))
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize=(10,5))
c=df_Lowerr_portion.corr()# correlation
sb.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %%
df_Lowerr_portion = df3[df3.Type.isin([4])]

# %%
sb.scatterplot(data=df_Lowerr_portion, x="price", y="Location")
# Out:
# <Axes: xlabel='price', ylabel='Location'>

# %%
df3.head()
# Out:
#       price  Location  Beds  Baths  Area_sq_yd  Type  near_by_schools  \
# 3  20200000         4     4      4         350     1                1
# 5  12000000         9     3      3         120     3                1
# 6  37500000        11     6      6         240     1                1
# 7  21000000        11     4      5         120     1                1
# 8  30000000         7     3      3         233     2                0
#
#    near_by_hospitals  near_by_airport  near_by_restaurant  \
# 3                  1                1                   1
# 5                  1                1                   1
# 6                  1                1                   1
# 7                  1                1                   1
# 8                  0                0                   0
#
#    near_by_public_transport  near_by_shopping_mall  parking_slot_available
# 3                         1                      1                       1
# ...

# %%
X = df3.drop('price', axis=1)

# %%
Y = df3['price']

# %%
X
# Out:
#       Location  Beds  Baths  Area_sq_yd  Type  near_by_schools  \
# 3            4     4      4         350     1                1
# 5            9     3      3         120     3                1
# 6           11     6      6         240     1                1
# 7           11     4      5         120     1                1
# 8            7     3      3         233     2                0
# ...        ...   ...    ...         ...   ...              ...
# 4969         3     3      3         267     2                1
# 4970         3     3      4         267     2                1
# 4971         3     3      3         211     2                0
# 4972         3     3      3         189     2                0
# 4973         3     3      3         189     2                0
#
#       near_by_hospitals  near_by_airport  near_by_restaurant  \
# 3                     1                1                   1
# 5                     1                1                   1
# ...

# %%
Y.shape
# Out:
# (4188,)

# %%
X.shape
# Out:
# (4188, 12)

# %% [markdown]
# Test Size is set at 0.2 means Training dataset is 80% and Testing dataset is
# 20%. Random state is mostly set at 0 or 42 as seed number for generator. This
# is necessary for reproducibility. With this statement examples are picked
# randomly to avoid biasness.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

X_train, X_valid, Y_train, Y_valid = train_test_split(
    X, Y, train_size=0.8, test_size=0.2, random_state=12)

# %%
X_train.shape
# Out:
# (3350, 12)

# %%
Y_train.shape
# Out:
# (3350,)

# %%
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import mean_absolute_percentage_error

model_SVR = svm.SVR()
model_SVR.fit(X_train,Y_train)
# Out:
# SVR()

# %%
import numpy as np

# %%
Y_pred = model_SVR.predict(np.array(X_valid))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
print(mean_absolute_percentage_error(Y_valid, Y_pred))
# Out:
# 0.8757164961104883

# %%
X_train.shape
# Out:
# (3350, 12)

# %%
Y_pred.shape
# Out:
# (838,)

# %%
X_valid.shape
# Out:
# (838, 12)

# %%
Y_pred.shape
# Out:
# (838,)

# %%
from sklearn.ensemble import RandomForestRegressor

X_train, X_valid, Y_train, Y_valid = train_test_split(
    X, Y, train_size=0.8, test_size=0.2, random_state=12)

model_RFR = RandomForestRegressor(n_estimators=10)
model_RFR.fit(X_train, Y_train)
Y_pred = c.predict(X_valid)

mean_absolute_percentage_error(Y_valid, Y_pred)
# Out:
# 0.15459796406643211

# %%
from sklearn.linear_model import LinearRegression

X_train, X_valid, Y_train, Y_valid = train_test_split(
    X, Y, train_size=0.8, test_size=0.2, random_state=12)

model_LR = LinearRegression()
model_LR.fit(X_train, Y_train)
Y_pred = model_LR.predict(X_valid)

print(mean_absolute_percentage_error(Y_valid, Y_pred))
# Out:
# 0.4050736250937782

# %%
X.head(1)
# Out:
#    Location  Beds  Baths  Area_sq_yd  Type  near_by_schools  \
# 3         4     4      4         350     1                1
#
#    near_by_hospitals  near_by_airport  near_by_restaurant  \
# 3                  1                1                   1
#
#    near_by_public_transport  near_by_shopping_mall  parking_slot_available
# 3                         1                      1                       1

# %%
act=Y.head(1)
act
# Out:
# 3    20200000
# Name: price, dtype: int64

# %%
# Replace the input data with the actual data you want to predict
input_data = [[4,  4, 4,350, 1, 1, 1,1,1,1,1,1]]
prediction = model_RFR.predict(input_data)
print(f'Predicted Diabetes Outcome: {prediction[0]}')
pred=prediction[0]
err=act-pred
print(err/act*100)
# Out:
# Predicted Diabetes Outcome: 19299047.48190476
# 3    4.460161
# Name: price, dtype: float64
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# <h1>Improvement Required</h1>
# There is need to find more effecient model as 15% error rate is still huge.<br/>
# Need to work for other city<br/>
# data must be collect for 3 year to check impact of major feature that is Year<br/>
# Re-evalute flow to check why data is not making major relation of location with price. As per general domain knowledge prespective it has majar impact<br/>
